# %% [markdown]
# # Remove anomalies
# - Ignore: pcb_18f_cc_12.png, pcb_48f_cc_26.png, pcb_50f_cc_26.png, pcb_21f_cc_12.png, pcb_40f_cc_21.png, pcb_44f_cc_16, pcb_37f_cc_11, pcb_42f_cc_13.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV data into a DataFrame
csv_file_path = r'C:\Users\iheiman\Desktop\CODE\ultralytics\ufl_pcb_size_of_components.csv'
ufl_pcb = pd.read_csv(csv_file_path)

ufl_pcb_resistor = ufl_pcb[ufl_pcb['Component'] == 0]

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=ufl_pcb_resistor, x='Width', y='Height', hue='Component', style='Component', palette='viridis', s=100)

# Add titles and labels
plt.title('Scatter Plot of Component Dimensions')
plt.xlabel('Width')
plt.ylabel('Height')

# Show the plot
plt.legend(title='Component')
plt.grid(True)
plt.show()

# %%
# Calculate mean and standard deviation
mean_height = df_cleaned['Height'].mean()
std_height = df_cleaned['Height'].std()
mean_width = df_cleaned['Width'].mean()
std_width = df_cleaned['Width'].std()

# Define threshold (e.g., 3 standard deviations)
height_threshold = mean_height + 3 * std_height
width_threshold = mean_width + 3 * std_width

# Filter data based on threshold
df_cleaned = df_cleaned[(df_cleaned['Height'] < height_threshold) & (df_cleaned['Width'] < width_threshold)]

# Create the scatter plot of cleaned data
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='Width', y='Height', color='blue', s=100)

# Add titles and labels
plt.title('Cleaned Scatter Plot of Resistor Dimensions')
plt.xlabel('Width')
plt.ylabel('Height')

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot for resistors across all 3 files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

ufl_pcb = pd.read_csv(r'C:\Users\iheiman\Desktop\CODE\ultralytics\ufl_pcb_size_of_components.csv')
wacv_pcb = pd.read_csv(r'C:\Users\iheiman\Desktop\CODE\ultralytics\wacv_size_of_components.csv')

# Filter rows where the Component column is equal to 0 (Resistor)
ufl_pcb_filtered = ufl_pcb[ufl_pcb['Component'] == 0]
wacv_pcb_filtered = wacv_pcb[wacv_pcb['Component'] == 0]

# Create the scatter plot
plt.figure(figsize=(10, 6))

# Plot UFL data
sns.scatterplot(data=ufl_pcb_filtered, x='Width', y='Height', color='blue', label='UFL_PCB', s=100)

# Plot WACV data
sns.scatterplot(data=wacv_pcb_filtered, x='Width', y='Height', color='red', label='WACV_PCB', s=100)

# Add titles and labels
plt.title('Scatter Plot of Resistor Dimensions from Different Sources')
plt.xlabel('Width')
plt.ylabel('Height')

# Show the legend
plt.legend(title='Source')

# Show the plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV data into DataFrames
ufl_pcb = pd.read_csv(r'C:\Users\iheiman\Downloads\size_of_components.csv')
# wacv_pcb = pd.read_csv(r'C:\Users\iheiman\Desktop\CODE\ultralytics\wacv_size_of_components.csv')

# Filter rows where the Component column is equal to 0
ufl_pcb_filtered = ufl_pcb[ufl_pcb['Component'] == 0]
# wacv_pcb_filtered = wacv_pcb[wacv_pcb['Component'] == 0]

# Sort the filtered DataFrames by Height and Width
ufl_pcb_filtered = ufl_pcb_filtered.sort_values(by=['Height', 'Width'])
# wacv_pcb_filtered = wacv_pcb_filtered.sort_values(by=['Height', 'Width'])

# Check if Filename column is affected correctly
print("UFL Data:")
print(ufl_pcb_filtered.head())
# print("\nWACV Data:")
# print(wacv_pcb_filtered.head())

# # Create the scatter plot
# plt.figure(figsize=(10, 6))

# # Plot UFL data
# sns.scatterplot(data=ufl_pcb_filtered, x='Width', y='Height', color='blue', label='UFL_PCB', s=100)

# # Plot WACV data
# sns.scatterplot(data=wacv_pcb_filtered, x='Width', y='Height', color='red', label='WACV_PCB', s=100)

# # Add titles and labels
# plt.title('Scatter Plot of Resistor Dimensions from Different Sources')
# plt.xlabel('Width')
# plt.ylabel('Height')

# # Show the legend
# plt.legend(title='Source')

# # Show the plot
# plt.grid(True)
# plt.show()
# Out:
# UFL Data:
#                                                Filename  Component  Height  \
# 7694  ../../DATASET/UFL_PCB_FULL/yolo_training/train...          0      12
# 4037  ../../DATASET/UFL_PCB_FULL/yolo_training/train...          0      13
# 4039  ../../DATASET/UFL_PCB_FULL/yolo_training/train...          0      13
# 4070  ../../DATASET/UFL_PCB_FULL/yolo_training/train...          0      13
# 4012  ../../DATASET/UFL_PCB_FULL/yolo_training/train...          0      13
#
#       Width
# 7694     28
# 4037     24
# 4039     24
# 4070     24
# 4012     25

# %%
vertices = [[2669, 1590], [2670, 1597], [2664, 1599], [2665, 1601], [2666, 1607], [2668, 1608], [2668, 1616], [2665, 1616], [2667, 1627], [2667, 1633], [2669, 1634], [2670, 1639], [2668, 1640], [2668, 1650], [2668, 1653], [2667, 1653], [2655, 1652], [2654, 1650], [2653, 1642], [2653, 1625], [2652, 1623], [2652, 1584], [2652, 1583], [2652, 1574], [2631, 1574], [2631, 1585], [2633, 1587], [2633, 1607], [2632, 1608], [2631, 1621], [2631, 1644], [2633, 1645], [2634, 1646], [2633, 1652], [2633, 1653], [2619, 1653], [2618, 1651], [2618, 1650], [2619, 1625], [2616, 1618], [2617, 1592], [2615, 1589], [2616, 1583], [2615, 1583], [2614, 1573], [2617, 1573], [2618, 1568], [2611, 1566], [2598, 1557], [2597, 1555], [2582, 1558], [2550, 1557], [2543, 1559], [2515, 1559], [2515, 1557], [2514, 1551], [2516, 1549], [2515, 1541], [2515, 1537], [2516, 1536], [2517, 1535], [2520, 1535], [2549, 1537], [2567, 1537], [2567, 1536], [2575, 1536], [2577, 1537], [2595, 1537], [2595, 1518], [2570, 1520], [2569, 1523], [2568, 1524], [2515, 1524], [2514, 1523], [2513, 1502], [2514, 1501], [2594, 1502], [2594, 1483], [2588, 1484], [2586, 1482], [2583, 1481], [2581, 1481], [2580, 1482], [2571, 1483], [2570, 1488], [2514, 1487], [2513, 1466], [2514, 1466], [2515, 1465], [2565, 1465], [2567, 1468], [2567, 1468], [2569, 1468], [2571, 1466], [2592, 1467], [2591, 1449], [2575, 1448], [2573, 1451], [2569, 1452], [2569, 1
1495], [2979, 1494], [2980, 1496], [2980, 1497], [2980, 1516], [2980, 1516], [2978, 1517], [2951, 1518], [2948, 1516], [2945, 1515], [2926, 1516], [2922, 1512], [2917, 1514], [2911, 1514], [2909, 1511], [2903, 1511], [2902, 1513], [2903, 1533], [2911, 1533], [2912, 1532], [2929, 1531], [2932, 1532], [2940, 1531], [2943, 1531], [2947, 1531], [2950, 1531], [2952, 1530], [2979, 1529], [2980, 1530], [2981, 1531], [2981, 1549], [2980, 1551], [2978, 1553], [2905, 1552], [2896, 1552], [2891, 1557], [2891, 1559], [2879, 1568], [2879, 1571], [2878, 1571], [2878, 1580], [2879, 1582], [2879, 1583], [2880, 1583], [2880, 1594], [2880, 1601], [2878, 1604], [2880, 1645], [2880, 1648], [2879, 1648], [2863, 1647], [2863, 1647], [2863, 1647], [2863, 1632], [2865, 1631], [2865, 1623], [2863, 1622], [2864, 1617], [2863, 1616], [2862, 1599], [2863, 1596], [2863, 1582], [2863, 1576], [2864, 1574], [2863, 1570], [2842, 1571], [2843, 1580], [2844, 1584], [2845, 1587], [2842, 1596], [2843, 1633], [2844, 1646], [2844, 1648], [2843, 1649], [2829, 1648], [2829, 1647], [2829, 1588], [2829, 1572], [2807, 1572], [2808, 1582], [2809, 1585], [2809, 1593], [2808, 1594], [2809, 1647], [2808, 1648], [2797, 1648], [2795, 1642], [2794, 1621], [2793, 1615], [2792, 1591], [2793, 1571], [2772, 1571], [2772, 1582], [2773, 1585], [2774, 1586], [2774, 1592], [2771, 1597], [2771, 1617], [2771, 1625], [2772, 1629], [2772, 1636], [2773, 1638], [2775, 1637], [2775, 1639], [2775, 1648], [2775, 1648], [2758, 1648], [2757, 1648], [2758, 1632], [2759, 1631], [2759, 1624], [2757, 1621], [2757, 1611], [2757, 1602], [2756, 1601], [2756, 1599], [2758, 1572], [2736, 1572], [2736, 1583], [2738, 1587], [2738, 1596], [2737, 1597], [2738, 1637], [2739, 1638], [2740, 1639], [2740, 1647], [2740, 1648], [2725, 1649], [2723, 1648], [2723, 1647], [2723, 1625], [2722, 1622], [2721, 1597], [2721, 1586], [2723, 1573], [2702, 1573], [2702, 1576], [2702, 1577], [2702, 1584], [2704, 1586], [2704, 1591], [2704, 1648], [2702, 1650], [2687, 1650], [2686, 1649], [2686, 1647], [2688, 1644], [2688, 1625], [2686, 1623], [2687, 1584], [2687, 1583], [2687, 1573], [2665, 1573], [2666, 1583], [2668, 1586]]

# %%
len(vertices)
# Out:
# 615

# %%
import cv2
img = cv2.imread(r"C:\Users\iheiman\Downloads\pcb_34f_cc_11.png")

# %%
# Draw dots on the image
dot_color = (0, 0, 255)  # Red color in BGR format (OpenCV uses BGR)
dot_radius = 5  # Radius of the dot circle

for vertex in vertices:
    cv2.circle(img, vertex, dot_radius, dot_color, -1)  # -1 means fill the circle

# Display the image with dots
plt.imshow(img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
